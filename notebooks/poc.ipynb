# %% [markdown]
# ## Init in-memory sql db

# %%
import json
import sqlite3
import os

def init_db():
    def load_jsonl(conn, table, path):
        with open(path) as f:
            for line in f:
                row = json.loads(line)
                cols = ", ".join(row.keys())
                vals = ", ".join(f":{k}" for k in row.keys())
                conn.execute(
                    f"INSERT INTO {table} ({cols}) VALUES ({vals})",
                    row
                )

    conn = sqlite3.connect(":memory:", check_same_thread=False)

    conn.executescript(open("../backend/db/schema.sql").read())

    load_jsonl(conn, "products", "../ai_services/data/products.jsonl")
    conn.commit()

    conn.row_factory = sqlite3.Row
    
    return conn

# %%
conn = init_db()

# %% [markdown]
# ## Init tools

# %% [markdown]
# ### Product search

# %%
from langchain.tools import tool

from backend.app.schemas.product import Product

@tool
def product_search(sql_query: str) -> list[Product]:
    """
    Search for products in the database using SQL.
    
    Database schema:
    - Table: products
    - Columns: id (INTEGER), name (TEXT), description (TEXT), price (REAL), stock_quantity (INTEGER), supplier (TEXT), review_stars (INTEGER 1-5)
    
    Examples:
    - SELECT * FROM products WHERE name LIKE '%bread%'
    - SELECT * FROM products WHERE price < 10 AND stock_quantity > 0
    - SELECT * FROM products WHERE name LIKE '%bacon%' OR name LIKE '%lettuce%' OR name LIKE '%tomato%'
    
    Always use LIKE with % wildcards for name searches. Quote string literals properly.
    """

    # Execute query
    cursor = conn.execute(sql_query)
    rows = cursor.fetchall()

    # Convert rows to Product objects
    products = [Product(**row) for row in rows]

    return products

# %%
product_search.invoke("SELECT * FROM products WHERE name LIKE '%bread%'")
# Out:
# [Product(id=1, name='Whole Wheat Bread Loaf', description='Sliced whole wheat sandwich bread, 24 oz loaf', price=3.49, stock_quantity=120, supplier='Golden Grain Foods', review_stars=4)]

# %% [markdown]
# ### Compliance checker

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

from backend.app.schemas.compliance_assessment import ComplianceAssessment

with open('../ai_services/data/policy.txt') as f:
    policy_text = f.read()

compliance_model = init_chat_model(model="gpt-4.1-mini", temperature=0)

compliance_agent = create_agent(
    system_prompt=f"""
    # Role
    You are a compliance checker for Direct Supply, a B2B procurement company that sells products to senior living communities. Your job is to evaluate product orders against company policies and identify any compliance violations.

    # Policy
    {policy_text}

    # Task
    Given a product order and the user's original query, determine if it complies with the company policies. If there are any violations, identify the specific products and the reasons for non-compliance. Return a structured report indicating whether the order is compliant and detailing any violations.
    """,
    response_format=ComplianceAssessment,
    model=compliance_model
)

# %%
from backend.app.schemas.product_order import ProductOrder
from backend.app.schemas.compliance_assessment import ComplianceAssessment

@tool
def compliance_checker(product_order: ProductOrder, original_user_query: str) -> ComplianceAssessment:
    """
    Evaluate a product order for compliance with company policies.
    """
    inputs = {
        'messages': [
            {
                'role': 'user', 
                'content': f"""
                Original User Query: {original_user_query}
                Product Order: {product_order.model_dump_json()}

                Determine if the order complies with the company policies. If there are any violations, identify the specific products and the reasons for non-compliance. Return a structured report indicating whether the order is compliant and detailing any violations.
                """
            }
        ]
    }
    assessment = compliance_agent.invoke(inputs)

    return assessment

# %% [markdown]
# ### Calculator

# %%
@tool
def calculator(expression: str) -> str:
    """
    A simple calculator tool that evaluates basic arithmetic expressions.
    Example inputs:
    - 2 + 2
    - 10 / 5
    - (3 * 4) - 5
    """
    try:
        # WARNING: eval can be dangerous in production code. This is just for demonstration.
        result = eval(expression, {"__builtins__": {}})
        return str(result)
    except Exception as e:
        return f"Error evaluating expression: {e}"

# %% [markdown]
# ## Init agent

# %%
from langchain.agents import create_agent
agent_model = init_chat_model(model="gpt-4.1-mini", temperature=0)
tools = [product_search, compliance_checker, calculator]
agent = create_agent(
    model=agent_model, 
    tools=tools,
    system_prompt="You are a procurement assistant that helps procurement specialists for Direct Supply, a B2B procurement company that sells products to senior living communities."
)

# %% [markdown]
# ## Invoke agent loop

# %%
# Initial messages from the user; rerun this cell to reset the conversation
initial_msg = input('Enter user message: ') or 'I need to procure products for 30 blt sandwiches. Create a valid product order for me.'

messages = {
    'messages': [
        {
            'role': 'user',
            'content': initial_msg
        }
    ],
}

print(f'User: {initial_msg}')
updated_messages = agent.invoke(messages)
messages = updated_messages
print(f'Agent: {messages["messages"][-1].content}')
print(f'Updated Messages:')
display(messages['messages'])
# Out:
# User: I need to procure products for 30 blt sandwiches. Create a valid product order for me.
# Agent: It appears there is no bacon product available in the current database. Would you like me to proceed with ordering the bread, lettuce, and tomato for the BLT sandwiches, or would you like to search for a substitute or alternative supplier for bacon?
# Updated Messages:
# [HumanMessage(content='I need to procure products for 30 blt sandwiches. Create a valid product order for me.', additional_kwargs={}, response_metadata={}, id='d08abb8f-9c0b-41e1-a89e-72a56c2c658f'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 314, 'total_tokens': 514, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uXJGowcJlogULZRMlUtnEYmEpNh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-4a9a-7430-bc32-4686b7a6a511-0', tool_calls=[{'name': 'product_search', 'args': {'sql_query': "SELECT * FROM products WHERE name LIKE '%bacon%' OR name LIKE '%lettuce%' OR name LIKE '%tomato%' OR name LIKE '%bread%'"}, 'id': 'call_4M5M9igrwsAgufDLmtWe6Tcl', 'type': 'tool_call'}, {'name': 'product_search', 'args': {'sql_query': "SELECT * FROM products WHERE name LIKE '%mayonnaise%' OR name LIKE '%cheese%' OR name LIKE '%turkey%' OR name LIKE '%ham%' OR name LIKE '%mustard%' OR name LIKE '%pickle%' OR name LIKE '%onion%' OR name LIKE '%avocado%' OR name LIKE '%egg%' OR name LIKE '%chicken%' OR name LIKE '%beef%' OR name LIKE '%pork%' OR name LIKE '%fish%' OR name LIKE '%vegetable%' OR name LIKE '%fruit%' OR name LIKE '%condiment%' OR name LIKE '%spread%' OR name LIKE '%sauce%'"}, 'id': 'call_a2AnX78hyVB25ElxAzCGbunx', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 314, 'output_tokens': 200, 'total_tokens': 514, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="[Product(id=1, name='Whole Wheat Bread Loaf', description='Sliced whole wheat sandwich bread, 24 oz loaf', price=3.49, stock_quantity=120, supplier='Golden Grain Foods', review_stars=4), Product(id=8, name='Canned Diced Tomatoes', description='Canned diced tomatoes in juice, 14.5 oz', price=1.39, stock_quantity=180, supplier='Red Vine Canning', review_stars=3)]", name='product_search', id='a19b70cb-75eb-409c-aac6-b112cb2bd005', tool_call_id='call_4M5M9igrwsAgufDLmtWe6Tcl'),
#  ToolMessage(content="[Product(id=3, name='Free Range Large Eggs', description='Dozen free-range large brown eggs', price=5.29, stock_quantity=60, supplier='Sunny Farm Collective', review_stars=5), Product(id=5, name='Boneless Skinless Chicken Breast', description='Raw boneless skinless chicken breast, 5 lb pack', price=18.99, stock_quantity=45, supplier='Prime Poultry Inc', review_stars=4), Product(id=10, name='Cheddar Cheese Block', description='Sharp cheddar cheese block, 2 lb', price=7.99, stock_quantity=55, supplier='DairyCraft Creamery', review_stars=5), Product(id=19, name='Frozen Ground Beef Patties', description='Frozen 80/20 ground beef patties, 5 lb box', price=21.99, stock_quantity=40, supplier='Midwest Meats Co', review_stars=4), Product(id=22, name='Frozen Pizza Cheese Blend', description='Shredded mozzarella and provolone blend, 5 lb', price=13.49, stock_quantity=50, supplier='Bella Italia Foods', review_stars=4), Product(id=25, name='Frozen Mixed Vegetables', description='Frozen peas, carrots, corn mix, 3 lb bag', price=4.49, stock_quantity=105, supplier='GreenFields Frozen', review_stars=4), Product(id=27, name='Chicken Noodle Soup', description='Canned chicken noodle soup, 19 oz', price=2.19, stock_quantity=160, supplier='HomeStyle Soups', review_stars=3), Product(id=28, name='Vegetable Cooking Oil', description='All-purpose vegetable oil, 1 gallon', price=10.99, stock_quantity=55, supplier='Golden Harvest Oils', review_stars=4)]", name='product_search', id='daf5f2c2-e491-40b1-b577-726b8d277386', tool_call_id='call_a2AnX78hyVB25ElxAzCGbunx'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 1026, 'total_tokens': 1040, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uXMr3aaVvzJFTyWqJRGdbyYGC2e', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-5536-7d30-90df-0e72cead0c7b-0', tool_calls=[{'name': 'calculator', 'args': {'expression': '30'}, 'id': 'call_VVc8skkvWoKZcoTRdAgOeshS', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1026, 'output_tokens': 14, 'total_tokens': 1040, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='30', name='calculator', id='60408001-87e4-43a4-9678-496c47cfe37d', tool_call_id='call_VVc8skkvWoKZcoTRdAgOeshS'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 1048, 'total_tokens': 1065, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uXNrmd8mDtw6xADlCiwrB5iXUtf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-5795-79a1-aa9d-d90625aedde6-0', tool_calls=[{'name': 'calculator', 'args': {'expression': '30 * 2'}, 'id': 'call_foCFBqnQ5hWh61AQS21OjTQM', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1048, 'output_tokens': 17, 'total_tokens': 1065, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='60', name='calculator', id='627eacc2-6d4b-496c-b051-edef760d6919', tool_call_id='call_foCFBqnQ5hWh61AQS21OjTQM'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 1073, 'total_tokens': 1145, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uXN3EKaOhOBHRAHIHmTv4OnJI8E', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-59ff-7e92-bb43-a67b03206797-0', tool_calls=[{'name': 'compliance_checker', 'args': {'product_order': {'line_items': [{'product_id': 1, 'quantity': 60}, {'product_id': 8, 'quantity': 30}, {'product_id': 10, 'quantity': 30}]}, 'original_user_query': 'I need to procure products for 30 blt sandwiches. Create a valid product order for me.'}, 'id': 'call_5XAuD0SrjgzwLDNgUnWi8s3o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1073, 'output_tokens': 72, 'total_tokens': 1145, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='{\'messages\': [HumanMessage(content=\'\\n                Original User Query: I need to procure products for 30 blt sandwiches. Create a valid product order for me.\\n                Product Order: {"line_items":[{"product_id":1,"quantity":60},{"product_id":8,"quantity":30},{"product_id":10,"quantity":30}]}\\n\\n                Determine if the order complies with the company policies. If there are any violations, identify the specific products and the reasons for non-compliance. Return a structured report indicating whether the order is compliant and detailing any violations.\\n                \', additional_kwargs={}, response_metadata={}, id=\'8d77ebba-4438-40c9-8f94-5361ed70db1b\'), AIMessage(content=\'{"is_compliant":false,"violations":[{"product_id":1,"reason":"Quantity ordered (60) exceeds the projected usage for 30 BLT sandwiches, likely overstocking without justification."}]}\', additional_kwargs={\'parsed\': None, \'refusal\': None}, response_metadata={\'token_usage\': {\'completion_tokens\': 48, \'prompt_tokens\': 720, \'total_tokens\': 768, \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0, \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\': 0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}}, \'model_provider\': \'openai\', \'model_name\': \'gpt-4.1-mini-2025-04-14\', \'system_fingerprint\': \'fp_75546bd1a7\', \'id\': \'chatcmpl-D6uXPSd75pyMr2dKJMgUNyAtp2JMr\', \'service_tier\': \'default\', \'finish_reason\': \'stop\', \'logprobs\': None}, id=\'lc_run--019c3c63-5ff0-7552-9c83-78e7c34e0510-0\', tool_calls=[], invalid_tool_calls=[], usage_metadata={\'input_tokens\': 720, \'output_tokens\': 48, \'total_tokens\': 768, \'input_token_details\': {\'audio\': 0, \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\': 0}})], \'structured_response\': ComplianceAssessment(violations=[Violation(product_id=1, reason=\'Quantity ordered (60) exceeds the projected usage for 30 BLT sandwiches, likely overstocking without justification.\')], is_compliant=False)}', name='compliance_checker', id='a2168730-8171-42a5-8115-1376d98d51e1', tool_call_id='call_5XAuD0SrjgzwLDNgUnWi8s3o'),
#  AIMessage(content='For 30 BLT sandwiches, you need 30 slices of bread (2 slices per sandwich), 30 portions of bacon, 30 portions of lettuce, and 30 portions of tomato. I initially ordered 60 slices of bread, which was flagged as overstocking. I will adjust the order to 60 slices of bread (which is 30 loaves if each loaf has 2 slices) and 30 each of bacon, lettuce, and tomato portions. Let me correct the order and check compliance again.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 131, 'prompt_tokens': 1693, 'total_tokens': 1824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_f4e2bc9c47', 'id': 'chatcmpl-D6uXQzme1jOD0n0bEkomNtEUvsvdm', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-6591-76d1-86b7-bc61e664ceff-0', tool_calls=[{'name': 'product_search', 'args': {'sql_query': "SELECT * FROM products WHERE name LIKE '%bacon%'"}, 'id': 'call_JHFU3bXlhHX5KbNi9e8YaJ7f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1693, 'output_tokens': 131, 'total_tokens': 1824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content=[], name='product_search', id='54c1bce8-09e3-4ea7-8197-b7abc41ca6a9', tool_call_id='call_JHFU3bXlhHX5KbNi9e8YaJ7f'),
#  AIMessage(content='It appears there is no bacon product available in the current database. Would you like me to proceed with ordering the bread, lettuce, and tomato for the BLT sandwiches, or would you like to search for a substitute or alternative supplier for bacon?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 1835, 'total_tokens': 1885, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_f4e2bc9c47', 'id': 'chatcmpl-D6uXTdrs7X0K2P2el7D6ouVaYP4Zy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c3c63-7263-7543-a997-7eeaf5de6c7a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1835, 'output_tokens': 50, 'total_tokens': 1885, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
# Continue the conversation with follow-up messages
if msg := input('Enter follow-up user message (or press Enter to skip): '):
    messages['messages'].append({
        'role': 'user',
        'content': msg
    })
    print(f'User: {msg}')
    updated_messages = agent.invoke(messages)
    print(f'Agent: {updated_messages["messages"][-1].content}')
    print(f'Updated Messages:')
    display(updated_messages['messages'])
# Out:
# User: yes
# Agent: There is no lettuce product available in the current database either. I will proceed with ordering the bread and tomato for the BLT sandwiches. Since bacon and lettuce are not available, you may need to source them separately. Here is the adjusted product order for 30 BLT sandwiches with the available items:
#
# - Whole Wheat Bread Loaf: 30 loaves (assuming each loaf has enough slices for 1 sandwich)
# - Canned Diced Tomatoes: 30 cans (as a tomato substitute)
#
# Would you like me to create this order for you?
# Updated Messages:
# [HumanMessage(content='I need to procure products for 30 blt sandwiches. Create a valid product order for me.', additional_kwargs={}, response_metadata={}, id='d08abb8f-9c0b-41e1-a89e-72a56c2c658f'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 314, 'total_tokens': 514, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uXJGowcJlogULZRMlUtnEYmEpNh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-4a9a-7430-bc32-4686b7a6a511-0', tool_calls=[{'name': 'product_search', 'args': {'sql_query': "SELECT * FROM products WHERE name LIKE '%bacon%' OR name LIKE '%lettuce%' OR name LIKE '%tomato%' OR name LIKE '%bread%'"}, 'id': 'call_4M5M9igrwsAgufDLmtWe6Tcl', 'type': 'tool_call'}, {'name': 'product_search', 'args': {'sql_query': "SELECT * FROM products WHERE name LIKE '%mayonnaise%' OR name LIKE '%cheese%' OR name LIKE '%turkey%' OR name LIKE '%ham%' OR name LIKE '%mustard%' OR name LIKE '%pickle%' OR name LIKE '%onion%' OR name LIKE '%avocado%' OR name LIKE '%egg%' OR name LIKE '%chicken%' OR name LIKE '%beef%' OR name LIKE '%pork%' OR name LIKE '%fish%' OR name LIKE '%vegetable%' OR name LIKE '%fruit%' OR name LIKE '%condiment%' OR name LIKE '%spread%' OR name LIKE '%sauce%'"}, 'id': 'call_a2AnX78hyVB25ElxAzCGbunx', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 314, 'output_tokens': 200, 'total_tokens': 514, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="[Product(id=1, name='Whole Wheat Bread Loaf', description='Sliced whole wheat sandwich bread, 24 oz loaf', price=3.49, stock_quantity=120, supplier='Golden Grain Foods', review_stars=4), Product(id=8, name='Canned Diced Tomatoes', description='Canned diced tomatoes in juice, 14.5 oz', price=1.39, stock_quantity=180, supplier='Red Vine Canning', review_stars=3)]", name='product_search', id='a19b70cb-75eb-409c-aac6-b112cb2bd005', tool_call_id='call_4M5M9igrwsAgufDLmtWe6Tcl'),
#  ToolMessage(content="[Product(id=3, name='Free Range Large Eggs', description='Dozen free-range large brown eggs', price=5.29, stock_quantity=60, supplier='Sunny Farm Collective', review_stars=5), Product(id=5, name='Boneless Skinless Chicken Breast', description='Raw boneless skinless chicken breast, 5 lb pack', price=18.99, stock_quantity=45, supplier='Prime Poultry Inc', review_stars=4), Product(id=10, name='Cheddar Cheese Block', description='Sharp cheddar cheese block, 2 lb', price=7.99, stock_quantity=55, supplier='DairyCraft Creamery', review_stars=5), Product(id=19, name='Frozen Ground Beef Patties', description='Frozen 80/20 ground beef patties, 5 lb box', price=21.99, stock_quantity=40, supplier='Midwest Meats Co', review_stars=4), Product(id=22, name='Frozen Pizza Cheese Blend', description='Shredded mozzarella and provolone blend, 5 lb', price=13.49, stock_quantity=50, supplier='Bella Italia Foods', review_stars=4), Product(id=25, name='Frozen Mixed Vegetables', description='Frozen peas, carrots, corn mix, 3 lb bag', price=4.49, stock_quantity=105, supplier='GreenFields Frozen', review_stars=4), Product(id=27, name='Chicken Noodle Soup', description='Canned chicken noodle soup, 19 oz', price=2.19, stock_quantity=160, supplier='HomeStyle Soups', review_stars=3), Product(id=28, name='Vegetable Cooking Oil', description='All-purpose vegetable oil, 1 gallon', price=10.99, stock_quantity=55, supplier='Golden Harvest Oils', review_stars=4)]", name='product_search', id='daf5f2c2-e491-40b1-b577-726b8d277386', tool_call_id='call_a2AnX78hyVB25ElxAzCGbunx'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 1026, 'total_tokens': 1040, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uXMr3aaVvzJFTyWqJRGdbyYGC2e', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-5536-7d30-90df-0e72cead0c7b-0', tool_calls=[{'name': 'calculator', 'args': {'expression': '30'}, 'id': 'call_VVc8skkvWoKZcoTRdAgOeshS', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1026, 'output_tokens': 14, 'total_tokens': 1040, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='30', name='calculator', id='60408001-87e4-43a4-9678-496c47cfe37d', tool_call_id='call_VVc8skkvWoKZcoTRdAgOeshS'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 1048, 'total_tokens': 1065, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uXNrmd8mDtw6xADlCiwrB5iXUtf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-5795-79a1-aa9d-d90625aedde6-0', tool_calls=[{'name': 'calculator', 'args': {'expression': '30 * 2'}, 'id': 'call_foCFBqnQ5hWh61AQS21OjTQM', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1048, 'output_tokens': 17, 'total_tokens': 1065, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='60', name='calculator', id='627eacc2-6d4b-496c-b051-edef760d6919', tool_call_id='call_foCFBqnQ5hWh61AQS21OjTQM'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 1073, 'total_tokens': 1145, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uXN3EKaOhOBHRAHIHmTv4OnJI8E', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-59ff-7e92-bb43-a67b03206797-0', tool_calls=[{'name': 'compliance_checker', 'args': {'product_order': {'line_items': [{'product_id': 1, 'quantity': 60}, {'product_id': 8, 'quantity': 30}, {'product_id': 10, 'quantity': 30}]}, 'original_user_query': 'I need to procure products for 30 blt sandwiches. Create a valid product order for me.'}, 'id': 'call_5XAuD0SrjgzwLDNgUnWi8s3o', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1073, 'output_tokens': 72, 'total_tokens': 1145, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='{\'messages\': [HumanMessage(content=\'\\n                Original User Query: I need to procure products for 30 blt sandwiches. Create a valid product order for me.\\n                Product Order: {"line_items":[{"product_id":1,"quantity":60},{"product_id":8,"quantity":30},{"product_id":10,"quantity":30}]}\\n\\n                Determine if the order complies with the company policies. If there are any violations, identify the specific products and the reasons for non-compliance. Return a structured report indicating whether the order is compliant and detailing any violations.\\n                \', additional_kwargs={}, response_metadata={}, id=\'8d77ebba-4438-40c9-8f94-5361ed70db1b\'), AIMessage(content=\'{"is_compliant":false,"violations":[{"product_id":1,"reason":"Quantity ordered (60) exceeds the projected usage for 30 BLT sandwiches, likely overstocking without justification."}]}\', additional_kwargs={\'parsed\': None, \'refusal\': None}, response_metadata={\'token_usage\': {\'completion_tokens\': 48, \'prompt_tokens\': 720, \'total_tokens\': 768, \'completion_tokens_details\': {\'accepted_prediction_tokens\': 0, \'audio_tokens\': 0, \'reasoning_tokens\': 0, \'rejected_prediction_tokens\': 0}, \'prompt_tokens_details\': {\'audio_tokens\': 0, \'cached_tokens\': 0}}, \'model_provider\': \'openai\', \'model_name\': \'gpt-4.1-mini-2025-04-14\', \'system_fingerprint\': \'fp_75546bd1a7\', \'id\': \'chatcmpl-D6uXPSd75pyMr2dKJMgUNyAtp2JMr\', \'service_tier\': \'default\', \'finish_reason\': \'stop\', \'logprobs\': None}, id=\'lc_run--019c3c63-5ff0-7552-9c83-78e7c34e0510-0\', tool_calls=[], invalid_tool_calls=[], usage_metadata={\'input_tokens\': 720, \'output_tokens\': 48, \'total_tokens\': 768, \'input_token_details\': {\'audio\': 0, \'cache_read\': 0}, \'output_token_details\': {\'audio\': 0, \'reasoning\': 0}})], \'structured_response\': ComplianceAssessment(violations=[Violation(product_id=1, reason=\'Quantity ordered (60) exceeds the projected usage for 30 BLT sandwiches, likely overstocking without justification.\')], is_compliant=False)}', name='compliance_checker', id='a2168730-8171-42a5-8115-1376d98d51e1', tool_call_id='call_5XAuD0SrjgzwLDNgUnWi8s3o'),
#  AIMessage(content='For 30 BLT sandwiches, you need 30 slices of bread (2 slices per sandwich), 30 portions of bacon, 30 portions of lettuce, and 30 portions of tomato. I initially ordered 60 slices of bread, which was flagged as overstocking. I will adjust the order to 60 slices of bread (which is 30 loaves if each loaf has 2 slices) and 30 each of bacon, lettuce, and tomato portions. Let me correct the order and check compliance again.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 131, 'prompt_tokens': 1693, 'total_tokens': 1824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_f4e2bc9c47', 'id': 'chatcmpl-D6uXQzme1jOD0n0bEkomNtEUvsvdm', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c63-6591-76d1-86b7-bc61e664ceff-0', tool_calls=[{'name': 'product_search', 'args': {'sql_query': "SELECT * FROM products WHERE name LIKE '%bacon%'"}, 'id': 'call_JHFU3bXlhHX5KbNi9e8YaJ7f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1693, 'output_tokens': 131, 'total_tokens': 1824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content=[], name='product_search', id='54c1bce8-09e3-4ea7-8197-b7abc41ca6a9', tool_call_id='call_JHFU3bXlhHX5KbNi9e8YaJ7f'),
#  AIMessage(content='It appears there is no bacon product available in the current database. Would you like me to proceed with ordering the bread, lettuce, and tomato for the BLT sandwiches, or would you like to search for a substitute or alternative supplier for bacon?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 1835, 'total_tokens': 1885, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_f4e2bc9c47', 'id': 'chatcmpl-D6uXTdrs7X0K2P2el7D6ouVaYP4Zy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c3c63-7263-7543-a997-7eeaf5de6c7a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1835, 'output_tokens': 50, 'total_tokens': 1885, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='adjust the product order', additional_kwargs={}, response_metadata={}, id='50a60cb3-5d9e-4e4e-86a6-bc0d3cd12d8a'),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='3be137c8-e0da-448c-81f1-78817e4d8942'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 1901, 'total_tokens': 1926, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1792}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uZDm040QRkvJC12bVT9vozRNeGy', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c3c65-14a5-7823-a140-ca3ce131bd49-0', tool_calls=[{'name': 'product_search', 'args': {'sql_query': "SELECT * FROM products WHERE name LIKE '%lettuce%'"}, 'id': 'call_jsziUeRS30DFV8XfiXh69jcr', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1901, 'output_tokens': 25, 'total_tokens': 1926, 'input_token_details': {'audio': 0, 'cache_read': 1792}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content=[], name='product_search', id='01b26fc2-6822-4fc5-9076-889636425bec', tool_call_id='call_jsziUeRS30DFV8XfiXh69jcr'),
#  AIMessage(content='There is no lettuce product available in the current database either. I will proceed with ordering the bread and tomato for the BLT sandwiches. Since bacon and lettuce are not available, you may need to source them separately. Here is the adjusted product order for 30 BLT sandwiches with the available items:\n\n- Whole Wheat Bread Loaf: 30 loaves (assuming each loaf has enough slices for 1 sandwich)\n- Canned Diced Tomatoes: 30 cans (as a tomato substitute)\n\nWould you like me to create this order for you?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 111, 'prompt_tokens': 1934, 'total_tokens': 2045, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1920}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_82dbabdb2c', 'id': 'chatcmpl-D6uZD9A2BALqz0NjaIdmQwK5JyTHo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c3c65-1764-73d0-8328-cad1e6a15c8c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1934, 'output_tokens': 111, 'total_tokens': 2045, 'input_token_details': {'audio': 0, 'cache_read': 1920}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
